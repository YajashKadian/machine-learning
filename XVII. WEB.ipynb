# %%
# !pip install requests

# %%
import requests

# %%
res = requests.get('https://www.google.com')

# %%
res.status_code
# Out:
# 200

# %%
res.headers
# Out:
# {'Date': 'Wed, 03 Jul 2019 07:07:06 GMT', 'Expires': '-1', 'Cache-Control': 'private, max-age=0', 'Content-Type': 'text/html; charset=ISO-8859-1', 'P3P': 'CP="This is not a P3P policy! See g.co/p3phelp for more info."', 'Content-Encoding': 'gzip', 'Server': 'gws', 'X-XSS-Protection': '0', 'X-Frame-Options': 'SAMEORIGIN', 'Set-Cookie': '1P_JAR=2019-07-03-07; expires=Fri, 02-Aug-2019 07:07:06 GMT; path=/; domain=.google.com, NID=187=WrenqQIUKZQgk8wnrKHrvdoL4ZkHp9CA2zAATj2fP9psCuQaeh5-9qOX1TM-47L_dHK1vUt7Ws2RB-WOh8fkNRkHxjteDYCxoG53eeNsLYISCsPZMAgIRiYgcpunwcFRvj4QhrYJzQ9CHfXAl5AIPbBgREwY4iJTf4tWuF9ZPYA; expires=Thu, 02-Jan-2020 07:07:06 GMT; path=/; domain=.google.com; HttpOnly', 'Alt-Svc': 'quic=":443"; ma=2592000; v="46,44,43,39"', 'Transfer-Encoding': 'chunked'}

# %%
res.content
# Out:
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="en-IN"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="AWLTxDL1MztbjblqkYNbKA==">(function(){window.google={kEI:\'GlQcXdruIdXbz7sP-YqSiAE\',kEXPI:\'0,1353804,1957,1641,782,1225,730,224,510,18,696,351,2082,1069,57,322,206,1017,228,888,87,281,32,208,55,329,2331445,329571,1294,12383,4855,32692,15247,867,12163,6381,854,2481,2,2,6801,364,8824,224,2212,266,5107,575,835,284,2,578,728,2431,59,2,2,2,1297,283,4040,3698,1269,774,2250,1407,2487,1996,9,4558,3601,669,1045,1,1812,1397,81,7,3,488,2044,5762,1,2841,305,5297,796,1220,38,918,756,1336,1336,28,1611,2736,48,1510,1503,2,215,1,415,3240,44,4783,2367,240,12,620,1139,1089,655,21,318,689,428,448,454,104,86,2,961,198,777,1,369,1316,705,757,97,392,29,400,261,731,1107,10,168,8,109,1018,506,989,174,967,48,553,11,15,9,12
# ...

# %%
baseUrl = "https://api.openweathermap.org/data/2.5/weather"
city = 'Delhi'
apiKey = 'bd138c521eb1f78add1aada6aa2d590e'
url = f"{baseUrl}?q={city}&appid={apiKey}"
print(url)
# Out:
# https://api.openweathermap.org/data/2.5/weather?q=Delhi&appid=bd138c521eb1f78add1aada6aa2d590e

# %%
res = requests.get(url)

# %%
res.status_code
# Out:
# 200

# %%
res.headers
# Out:
# {'Server': 'openresty', 'Date': 'Wed, 03 Jul 2019 07:17:46 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '452', 'Connection': 'keep-alive', 'X-Cache-Key': '/data/2.5/weather?q=delhi', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true', 'Access-Control-Allow-Methods': 'GET, POST'}

# %%
res.content
# Out:
# b'{"coord":{"lon":77.22,"lat":28.65},"weather":[{"id":721,"main":"Haze","description":"haze","icon":"50d"}],"base":"stations","main":{"temp":309.16,"pressure":1001,"humidity":53,"temp_min":308.15,"temp_max":309.82},"visibility":3500,"wind":{"speed":3.6,"deg":110},"clouds":{"all":75},"dt":1562138170,"sys":{"type":1,"id":9165,"message":0.007,"country":"IN","sunrise":1562111832,"sunset":1562161977},"timezone":19800,"id":1273294,"name":"Delhi","cod":200}'

# %%
data = res.json()

# %%
data
# Out:
# {'coord': {'lon': 77.22, 'lat': 28.65},
#  'weather': [{'id': 721,
#    'main': 'Haze',
#    'description': 'haze',
#    'icon': '50d'}],
#  'base': 'stations',
#  'main': {'temp': 309.16,
#   'pressure': 1001,
#   'humidity': 53,
#   'temp_min': 308.15,
#   'temp_max': 309.82},
#  'visibility': 3500,
#  'wind': {'speed': 3.6, 'deg': 110},
#  'clouds': {'all': 75},
#  'dt': 1562138170,
#  'sys': {'type': 1,
#   'id': 9165,
#   'message': 0.007,
#   'country': 'IN',
#   'sunrise': 1562111832,
#   'sunset': 1562161977},
#  'timezone': 19800,
#  'id': 1273294,
#  'name': 'Delhi',
#  'cod': 200}

# %%
data['main']['temp_min']-273.15
# Out:
# 35.0

# %%
data['main']['temp_max']-273.15
# Out:
# 36.670000000000016

# %%
data['weather'][0]['description']
# Out:
# 'haze'

# %%
url ="http://graph.facebook.com/410/picture?type=large"
res = requests.get(url)

# %%
res.status_code
# Out:
# 200

# %%
res.headers
# Out:
# {'Last-Modified': 'Wed, 14 Nov 2018 03:57:11 GMT', 'x-haystack-needlechecksum': '3087929266', 'x-needle-checksum': '515883901', 'Content-Type': 'image/jpeg', 'x-fb-config-version-olb-prod': '516', 'timing-allow-origin': '*', 'Access-Control-Allow-Origin': '*', 'Cache-Control': 'max-age=1209600, no-transform', 'x-enc-origin-req-handler': 'AcJNLjMovSecXz-z7xa0sTdMVY6_dsknEzOvCTBfuq0WHaWQbqu2fuDk72UliRikxEIsaB2nkJ2SpCct', 'X-FB-TRIP-ID': '1620309528', 'X-FB-Config-Version-ELB-PROD': '516', 'Date': 'Wed, 03 Jul 2019 07:36:13 GMT', 'X-FB-Edge-Debug': 'mRu5SPUddqDaTZOU3L4fKhiKI5donQ_OioqdnxoXTCHlmZGiH8jy_bR0A84JXoPGgelbEWjrzgipONlU48mcYg', 'Access-Control-Expose-Headers': 'X-FB-CEC-Video-Limit', 'Connection': 'keep-alive', 'Content-Length': '12096'}

# %%
res.content
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x02\x00\x00\x01\x00\x01\x00\x00\xff\xed\x00\x9cPhotoshop 3.0\x008BIM\x04\x04\x00\x00\x00\x00\x00\x80\x1c\x02g\x00\x14UtDyR-55JN2J-_KUOwMh\x1c\x02(\x00bFBMD01000abe030000a6060000900b0000510c0000580d000067130000981c0000441d0000521e0000941f0000402f0000\xff\xe2\x02\x1cICC_PROFILE\x00\x01\x01\x00\x00\x02\x0clcms\x02\x10\x00\x00mntrRGB XYZ \x07\xdc\x00\x01\x00\x19\x00\x03\x00)\x009acspAPPL\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf6\xd6\x00\x01\x00\x00\x00\x00\xd3-lcms\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\ndesc\x00\x00\x00\xfc\x00\x00\x00^cprt\x00\x00\x01\\\x00\x00\x00\x0bwtpt\x00\x00\x01h\x00\x00\x00\x14bkpt\x00\x00\x01|\x00\x00\x00\x14rXYZ\x00\x00\x01\x90\x00\x00\x00\x14gXYZ\x00\x00\x01\xa4\x00\x00\x00\x14bXYZ\x00\x00\x01\xb8\x00\x00\x00\
# ...

# %%
with open ('/users/yajashkadian/data/output/facebook.jpeg','wb') as file:
     file.write(res.content)

# %%
# !pip install html5lib

# %%
# !pip install bs4

# %%
from bs4 import BeautifulSoup

# %%
url ='https://www.flipkart.com'

# %%
res =requests.get(url)
res.status_code
# Out:
# 200

# %%
res.headers
# Out:
# {'Server': 'nginx', 'Date': 'Wed, 03 Jul 2019 07:41:10 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Content-Security-Policy': "script-src 'self' 'unsafe-eval' https://*.flixcart.com https://*.flixcart.net https://flipkart.d1.sc.omtrdc.net https://dpm.demdex.net https://sslwidget.criteo.com https://widget.as.criteo.com https://tnc.phonepe.com 'nonce-12380831675935848786'; style-src 'self' 'unsafe-inline' https://*.flixcart.com https://tnc.phonepe.com https://*.flixcart.net; img-src 'self' data: blob: https://*.flixcart.com https://*.flixcart.net https://flipkart.d1.sc.omtrdc.net https://www.facebook.com https://*.fkapi.net https://googleads.g.doubleclick.net https://www.google.com https://www.google.co.in https://www.googleadservices.com https://sp.analytics.yahoo.com https://bat.bing.com https://bat.r.msn.com https://www.payzippy.com https://tnc.phonepe.com; font-src 'self' data: https://*.flixcart.com https://tnc.phonepe.com https://*.flixcart.n
# ...

# %%
res.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\t<link href="https://rukminim1.flixcart.com" rel="dns-prefetch" />\n\t<link href="https://img1a.flixcart.com" rel="dns-prefetch" />\n\t<link rel="stylesheet" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.46f631.css" />\n\n\t<link rel="preload" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" as="image">\n\n\t<meta http-equiv="Content-type" content="text/html; charset=utf-8"/>\n\t<meta http-equiv="X-UA-Compatible" content="IE=Edge" />\n\t<meta property="fb:page_id" content="102988293558"/>\n\t<meta property="fb:admins" content="658873552,624500995,100000233612389"/>\n\t<meta name="robots" content="noodp" />\n\n\t<link rel=\'shortcut icon\' href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" />\n\n\t<link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/>\n\n\t<meta property="og:type" content="website"/>\n\t<meta name="og_site_name" pr
# ...

# %%
soup = BeautifulSoup(res.content,'html5lib')

# %%
imgList = soup.findAll('img',{'class':'_2VeolH'})
len(imgList)
# Out:
# 13

# %%
imgList[0]['src']
# Out:
# '//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/flipkart-plus_4ee2f9.png'

# %%
imgList
# Out:
# [<img alt="JBL" class="_2VeolH _3I5S6S" src="https://rukminim1.flixcart.com/flap/50/50/image/c7f524f03bad03ea.jpg?q=50"/>,
#  <img alt="Flipstart Days" class="_2VeolH" src="https://rukminim1.flixcart.com/flap/844/140/image/1cb21f5a1d58a7df.jpg?q=50"/>,
#  <img alt="Large_DT_HPW3_FSdays_1-3JULY" class="_2VeolH _3I5S6S" src="https://rukminim1.flixcart.com/flap/50/50/image/0aaa0f3b7e971a8b.jpg?q=50"/>,
#  <img alt="LS-1stJuly-HPW-4" class="_2VeolH _3I5S6S" src="https://rukminim1.flixcart.com/flap/50/50/image/9fb7eed2d3a90304.jpg?q=50"/>,
#  <img alt="Intel" class="_2VeolH _3I5S6S" src="https://rukminim1.flixcart.com/flap/50/50/image/184e7f47b2dfac90.jpg?q=50"/>,
#  <img alt="a" class="_2VeolH _3I5S6S" src="https://rukminim1.flixcart.com/flap/50/50/image/0b5984959b8c6b7d.jpg?q=50"/>,
#  <img alt="Clone of Cat_Mob_Hpw_7" class="_2VeolH _3I5S6S" src="https://rukminim1.flixcart.com/flap/50/50/image/75a611c14c5787a9.jpg?q=50"/>,
# ...

# %%
[i ['class'] for i in imgList]
# Out:
# [['_2VeolH', '_3I5S6S'],
#  ['_2VeolH'],
#  ['_2VeolH', '_3I5S6S'],
#  ['_2VeolH', '_3I5S6S'],
#  ['_2VeolH', '_3I5S6S'],
#  ['_2VeolH', '_3I5S6S'],
#  ['_2VeolH', '_3I5S6S'],
#  ['_2VeolH', '_3I5S6S'],
#  ['_2VeolH'],
#  ['_2VeolH', '_3I5S6S'],
#  ['_2VeolH', '_3I5S6S'],
#  ['_2VeolH', '_3I5S6S'],
#  ['_2VeolH', '_3I5S6S']]

# %%
imgList[1]['src']
# Out:
# 'https://rukminim1.flixcart.com/flap/844/140/image/1cb21f5a1d58a7df.jpg?q=50'

# %%
# !pip install selenium
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/80/d6/4294f0b4bce4de0abf13e17190289f9d0613b0a44e5dd6a7f5ca98459853/selenium-3.141.0-py2.py3-none-any.whl
# ...
